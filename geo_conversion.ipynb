# %%
import geopandas as gpd
from shapely.geometry import mapping
import pandas as pd
from shapely.geometry import Point

# %%
gdf_polygons = gpd.read_file('data/World_EEZ_v11_20191118/eez_v11.shp')
gdf_polygons
# Out:
#        MRGID                                            GEONAME  MRGID_TER1  \
# 0     8444.0             American Samoa Exclusive Economic Zone      8670.0
# 1     8379.0                  Ascension Exclusive Economic Zone      8620.0
# 2     8446.0               Cook Islands Exclusive Economic Zone      8672.0
# 3     8389.0  Overlapping claim Falkland / Malvinas Islands:...      8623.0
# 4     8440.0          French Polynesian Exclusive Economic Zone      8656.0
# ..       ...                                                ...         ...
# 276   5693.0                    Spanish Exclusive Economic Zone      2185.0
# 277  62589.0         Chagos Archipelago Exclusive Economic Zone      8616.0
# 278   8383.0  Overlapping claim South Georgia and South Sand...      8624.0
# 279   8402.0                  Bermudian Exclusive Economic Zone      8636.0
# 280   8456.0              United States Exclusive Economic Zone      2204.0
#
#               POL_TYPE  MRGID_SOV1  \
# 0                200NM      2204.0
# 1                200NM      2208.0
# 2                200NM      2227.0
# 3    Overlapping claim      2208.0
# 4                200NM        17.0
# ..                 ...         ...
# 276              200NM      2185.0
# 277             200 NM      8614.0
# 278  Overlapping claim      2208.0
# 279              200NM      2208.0
# 280              200NM      2204.0
#
#                                        TERRITORY1 ISO_TER1      SOVEREIGN1  \
# 0                                  American Samoa      ASM   United States
# 1                                       Ascension      SHN  United Kingdom
# 2                                    Cook Islands      COK     New Zealand
# 3                     Falkland / Malvinas Islands      FLK  United Kingdom
# 4                                French Polynesia      PYF          France
# ..                                            ...      ...             ...
# 276                                         Spain      ESP           Spain
# 277                            Chagos Archipelago      NaN       Mauritius
# 278  South Georgia and the South Sandwich Islands      SGS  United Kingdom
# 279                                       Bermuda      BMU  United Kingdom
# 280                                 United States      USA   United States
#
#      MRGID_TER2  MRGID_SOV2  ... ISO_SOV1 ISO_SOV2 ISO_SOV3  UN_SOV1  UN_SOV2  \
# 0           0.0         0.0  ...      USA      NaN      NaN      840      NaN
# 1           0.0         0.0  ...      GBR      NaN      NaN      826      NaN
# 2           0.0         0.0  ...      NZL      NaN      NaN      554      NaN
# 3        8623.0      2149.0  ...      GBR      ARG      NaN      826     32.0
# 4           0.0         0.0  ...      FRA      NaN      NaN      250      NaN
# ..          ...         ...  ...      ...      ...      ...      ...      ...
# 276         0.0         0.0  ...      ESP      NaN      NaN      724      NaN
# 277         0.0         0.0  ...      MUS      NaN      NaN      480      NaN
# 278      8624.0      2149.0  ...      GBR      ARG      NaN      826     32.0
# 279         0.0         0.0  ...      GBR      NaN      NaN      826      NaN
# 280         0.0         0.0  ...      USA      NaN      NaN      840      NaN
#
#     UN_SOV3 UN_TER1 UN_TER2  UN_TER3  \
# 0       NaN    16.0     NaN      NaN
# 1       NaN   654.0     NaN      NaN
# 2       NaN   184.0     NaN      NaN
# 3       NaN   238.0   238.0      NaN
# 4       NaN   258.0     NaN      NaN
# ..      ...     ...     ...      ...
# 276     NaN   724.0     NaN      NaN
# 277     NaN     NaN     NaN      NaN
# 278     NaN   239.0   239.0      NaN
# 279     NaN    60.0     NaN      NaN
# 280     NaN   840.0     NaN      NaN
#
#                                               geometry
# 0    POLYGON ((-166.64112 -17.55527, -166.64194 -17...
# 1    POLYGON ((-10.93328 -7.88745, -10.93324 -7.889...
# 2    POLYGON ((-159.27579 -5.80051, -158.38466 -6.3...
# 3    POLYGON ((-58.54196 -56.22782, -61.62049 -53.7...
# 4    MULTIPOLYGON (((-135.93245 -7.89001, -135.9290...
# ..                                                 ...
# 276  MULTIPOLYGON (((4.54375 42.44867, 4.86147 42.0...
# 277  POLYGON ((75.83452 -5.23039, 75.83260 -5.31997...
# 278  POLYGON ((-37.13953 -50.64608, -37.03619 -50.6...
# 279  POLYGON ((-60.70499 32.39114, -60.70499 32.390...
# 280  MULTIPOLYGON (((-67.28418 45.19126, -67.28403 ...
#
# [281 rows x 32 columns]

# %%
df = pd.read_csv("data/lists-Reefers-2023-03-03_06-54.csv")
# df = df[['MMSI', 'Latitude', 'Longitude']]
# df = df.dropna()

# %%
df['coordinates'] = list(zip(df['Longitude'], df['Latitude']))
df['coordinates']
# Out:
# 0         (11.668572, 57.577002)
# 1        (105.801953, -5.927718)
# 2       (-122.510783, 48.758683)
# 3        (122.446303, 36.883225)
# 4                  (199.0, 99.0)
#                   ...
# 1859         (145.45, 42.718333)
# 1860      (133.192818, 35.74963)
# 1861    (-73.586935, -43.505577)
# 1862      (118.65124, 24.396132)
# 1863     (121.997692, 29.764608)
# Name: coordinates, Length: 1864, dtype: object

# %%
df.coordinates = df.coordinates.apply(Point)
df.coordinates
# Out:
# 0         POINT (11.668572 57.577002)
# 1        POINT (105.801953 -5.927718)
# 2       POINT (-122.510783 48.758683)
# 3        POINT (122.446303 36.883225)
# 4                      POINT (199 99)
#                     ...
# 1859         POINT (145.45 42.718333)
# 1860      POINT (133.192818 35.74963)
# 1861    POINT (-73.586935 -43.505577)
# 1862      POINT (118.65124 24.396132)
# 1863     POINT (121.997692 29.764608)
# Name: coordinates, Length: 1864, dtype: object

# %%
gdf_points = gpd.GeoDataFrame(df, geometry='coordinates')
gdf_points
# Out:
#       Antenna Offset from Bow  Antenna Offset from Port  Beam  \
# 0                        77.0                      13.0  16.0
# 1                         0.0                       0.0   0.0
# 2                       119.0                       6.0  23.0
# 3                        25.0                       3.0   6.0
# 4                         NaN                       NaN   NaN
# ...                       ...                       ...   ...
# 1859                     56.0                       5.0  11.0
# 1860                      0.0                       0.0   0.0
# 1861                     14.0                       5.0  12.0
# 1862                      0.0                       0.0   0.0
# 1863                     92.0                       7.0  16.0
#
#                            Builder Call Sign  Cargo Type  \
# 0                              NaN     D5KN7    9-NoInfo
# 1                     Arie Taryo P    YB3789  0-AllShips
# 2                        Kitanihon     3FAF5  0-AllShips
# 3     Rongcheng Haida Shipbuilding     BBFB7  5-Reserved
# 4                   Flensburger KG       NaN         NaN
# ...                            ...       ...         ...
# 1859                     Wakamatsu     UBMG8  0-AllShips
# 1860             Watanabe Nagasaki    JD3401  0-AllShips
# 1861              Detroit Chile SA    CB9953  0-AllShips
# 1862                           NaN     BVBR7  8-Reserved
# 1863         Kyokuyo Shipyard Corp      HOAJ  0-AllShips
#
#                   Class Society    COG Beneficial Owner  Deadweight  ...  \
# 0                           NaN   98.3              NaN         NaN  ...
# 1                           NaN  221.3        Indonesia         NaN  ...
# 2           Nippon Kaiji Kyokai  304.0            Japan     10608.0  ...
# 3                           NaN   26.4            China         NaN  ...
# 4            Det Norske Veritas    0.0      Netherlands     10320.0  ...
# ...                         ...    ...              ...         ...  ...
# 1859  Russian Maritime Register  238.0           Russia      1056.0  ...
# 1860                        NaN  129.5            Japan         NaN  ...
# 1861                        NaN  211.2            Chile      1049.0  ...
# 1862                        NaN  223.7              NaN         NaN  ...
# 1863        Nippon Kaiji Kyokai  311.0      South Korea      5609.0  ...
#
#      Status             Sub Status                  Subtype  \
# 0       NaN                    NaN                      NaN
# 1         S  In Service/Commission             Fish Carrier
# 2         S  In Service/Commission  Refrigerated Cargo Ship
# 3         S  In Service/Commission             Fish Carrier
# 4         F               Launched         Ro-Ro Cargo Ship
# ...     ...                    ...                      ...
# 1859      S  In Service/Commission  Refrigerated Cargo Ship
# 1860      S  In Service/Commission           Fishing Vessel
# 1861      S  In Service/Commission             Fish Carrier
# 1862    NaN                    NaN                      NaN
# 1863      S  In Service/Commission  Refrigerated Cargo Ship
#
#          Time of Fix (formatted) Time of Fix (s since 1970) Vessel Type  \
# 0     "2022-06-06T15:14:15.000Z"                 1654528455     7-Cargo
# 1     "2023-01-31T21:51:28.000Z"                 1675201888  30-Fishing
# 2     "2023-03-03T18:49:34.000Z"                 1677869374     7-Cargo
# 3     "2021-05-13T23:50:53.000Z"                 1620949853     7-Cargo
# 4     "2023-03-03T06:48:32.000Z"                 1677826112         NaN
# ...                          ...                        ...         ...
# 1859  "2023-03-03T16:58:47.000Z"                 1677862727     7-Cargo
# 1860  "2023-02-22T14:11:59.000Z"                 1677075119  30-Fishing
# 1861  "2023-03-03T18:27:00.000Z"                 1677868020     7-Cargo
# 1862  "2021-03-20T15:17:00.000Z"                 1616253420    8-Tanker
# 1863  "2023-03-03T18:52:58.000Z"                 1677869578     7-Cargo
#
#       Year Built  Design Speed  Double Hull              coordinates
# 0            NaN           NaN          NaN    POINT (11.669 57.577)
# 1     2014-12-25           0.0          NaN   POINT (105.802 -5.928)
# 2     2009-09-05          19.6          NaN  POINT (-122.511 48.759)
# 3     0000-00-00           0.0           SH   POINT (122.446 36.883)
# 4     2022-06-17          20.0          NaN   POINT (199.000 99.000)
# ...          ...           ...          ...                      ...
# 1859  1977-11-18          12.0          NaN   POINT (145.450 42.718)
# 1860  2012-06-23           0.0           SH   POINT (133.193 35.750)
# 1861  2007-08-10           0.0           SH  POINT (-73.587 -43.506)
# 1862         NaN           NaN          NaN   POINT (118.651 24.396)
# 1863  1989-07-14          14.5          NaN   POINT (121.998 29.765)
#
# [1864 rows x 46 columns]

# %%
gdf_points.crs = gdf_polygons.crs
gdf_points.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf_polygons
# Out:
#        MRGID                                            GEONAME  MRGID_TER1  \
# 0     8444.0             American Samoa Exclusive Economic Zone      8670.0
# 1     8379.0                  Ascension Exclusive Economic Zone      8620.0
# 2     8446.0               Cook Islands Exclusive Economic Zone      8672.0
# 3     8389.0  Overlapping claim Falkland / Malvinas Islands:...      8623.0
# 4     8440.0          French Polynesian Exclusive Economic Zone      8656.0
# ..       ...                                                ...         ...
# 276   5693.0                    Spanish Exclusive Economic Zone      2185.0
# 277  62589.0         Chagos Archipelago Exclusive Economic Zone      8616.0
# 278   8383.0  Overlapping claim South Georgia and South Sand...      8624.0
# 279   8402.0                  Bermudian Exclusive Economic Zone      8636.0
# 280   8456.0              United States Exclusive Economic Zone      2204.0
#
#               POL_TYPE  MRGID_SOV1  \
# 0                200NM      2204.0
# 1                200NM      2208.0
# 2                200NM      2227.0
# 3    Overlapping claim      2208.0
# 4                200NM        17.0
# ..                 ...         ...
# 276              200NM      2185.0
# 277             200 NM      8614.0
# 278  Overlapping claim      2208.0
# 279              200NM      2208.0
# 280              200NM      2204.0
#
#                                        TERRITORY1 ISO_TER1      SOVEREIGN1  \
# 0                                  American Samoa      ASM   United States
# 1                                       Ascension      SHN  United Kingdom
# 2                                    Cook Islands      COK     New Zealand
# 3                     Falkland / Malvinas Islands      FLK  United Kingdom
# 4                                French Polynesia      PYF          France
# ..                                            ...      ...             ...
# 276                                         Spain      ESP           Spain
# 277                            Chagos Archipelago      NaN       Mauritius
# 278  South Georgia and the South Sandwich Islands      SGS  United Kingdom
# 279                                       Bermuda      BMU  United Kingdom
# 280                                 United States      USA   United States
#
#      MRGID_TER2  MRGID_SOV2  ... ISO_SOV1 ISO_SOV2 ISO_SOV3  UN_SOV1  UN_SOV2  \
# 0           0.0         0.0  ...      USA      NaN      NaN      840      NaN
# 1           0.0         0.0  ...      GBR      NaN      NaN      826      NaN
# 2           0.0         0.0  ...      NZL      NaN      NaN      554      NaN
# 3        8623.0      2149.0  ...      GBR      ARG      NaN      826     32.0
# 4           0.0         0.0  ...      FRA      NaN      NaN      250      NaN
# ..          ...         ...  ...      ...      ...      ...      ...      ...
# 276         0.0         0.0  ...      ESP      NaN      NaN      724      NaN
# 277         0.0         0.0  ...      MUS      NaN      NaN      480      NaN
# 278      8624.0      2149.0  ...      GBR      ARG      NaN      826     32.0
# 279         0.0         0.0  ...      GBR      NaN      NaN      826      NaN
# 280         0.0         0.0  ...      USA      NaN      NaN      840      NaN
#
#     UN_SOV3 UN_TER1 UN_TER2  UN_TER3  \
# 0       NaN    16.0     NaN      NaN
# 1       NaN   654.0     NaN      NaN
# 2       NaN   184.0     NaN      NaN
# 3       NaN   238.0   238.0      NaN
# 4       NaN   258.0     NaN      NaN
# ..      ...     ...     ...      ...
# 276     NaN   724.0     NaN      NaN
# 277     NaN     NaN     NaN      NaN
# 278     NaN   239.0   239.0      NaN
# 279     NaN    60.0     NaN      NaN
# 280     NaN   840.0     NaN      NaN
#
#                                               geometry
# 0    POLYGON ((-166.64112 -17.55527, -166.64194 -17...
# 1    POLYGON ((-10.93328 -7.88745, -10.93324 -7.889...
# 2    POLYGON ((-159.27579 -5.80051, -158.38466 -6.3...
# 3    POLYGON ((-58.54196 -56.22782, -61.62049 -53.7...
# 4    MULTIPOLYGON (((-135.93245 -7.89001, -135.9290...
# ..                                                 ...
# 276  MULTIPOLYGON (((4.54375 42.44867, 4.86147 42.0...
# 277  POLYGON ((75.83452 -5.23039, 75.83260 -5.31997...
# 278  POLYGON ((-37.13953 -50.64608, -37.03619 -50.6...
# 279  POLYGON ((-60.70499 32.39114, -60.70499 32.390...
# 280  MULTIPOLYGON (((-67.28418 45.19126, -67.28403 ...
#
# [281 rows x 32 columns]

# %%
sjoin = gpd.sjoin(gdf_points, gdf_polygons, how='left', predicate='within')

# %%
df_join = pd.DataFrame(sjoin)
sjoin
# Out:
#       Antenna Offset from Bow  Antenna Offset from Port  Beam  \
# 0                        77.0                      13.0  16.0
# 1                         0.0                       0.0   0.0
# 2                       119.0                       6.0  23.0
# 3                        25.0                       3.0   6.0
# 4                         NaN                       NaN   NaN
# ...                       ...                       ...   ...
# 1859                     56.0                       5.0  11.0
# 1860                      0.0                       0.0   0.0
# 1861                     14.0                       5.0  12.0
# 1862                      0.0                       0.0   0.0
# 1863                     92.0                       7.0  16.0
#
#                            Builder Call Sign  Cargo Type  \
# 0                              NaN     D5KN7    9-NoInfo
# 1                     Arie Taryo P    YB3789  0-AllShips
# 2                        Kitanihon     3FAF5  0-AllShips
# 3     Rongcheng Haida Shipbuilding     BBFB7  5-Reserved
# 4                   Flensburger KG       NaN         NaN
# ...                            ...       ...         ...
# 1859                     Wakamatsu     UBMG8  0-AllShips
# 1860             Watanabe Nagasaki    JD3401  0-AllShips
# 1861              Detroit Chile SA    CB9953  0-AllShips
# 1862                           NaN     BVBR7  8-Reserved
# 1863         Kyokuyo Shipyard Corp      HOAJ  0-AllShips
#
#                   Class Society    COG Beneficial Owner  Deadweight  ...  \
# 0                           NaN   98.3              NaN         NaN  ...
# 1                           NaN  221.3        Indonesia         NaN  ...
# 2           Nippon Kaiji Kyokai  304.0            Japan     10608.0  ...
# 3                           NaN   26.4            China         NaN  ...
# 4            Det Norske Veritas    0.0      Netherlands     10320.0  ...
# ...                         ...    ...              ...         ...  ...
# 1859  Russian Maritime Register  238.0           Russia      1056.0  ...
# 1860                        NaN  129.5            Japan         NaN  ...
# 1861                        NaN  211.2            Chile      1049.0  ...
# 1862                        NaN  223.7              NaN         NaN  ...
# 1863        Nippon Kaiji Kyokai  311.0      South Korea      5609.0  ...
#
#        AREA_KM2  ISO_SOV1  ISO_SOV2  ISO_SOV3 UN_SOV1 UN_SOV2  UN_SOV3  \
# 0      155347.0       SWE       NaN       NaN   752.0     NaN      NaN
# 1     6020917.0       IDN       NaN       NaN   360.0     NaN      NaN
# 2     2451023.0       USA       NaN       NaN   840.0     NaN      NaN
# 3      963556.0       CHN       NaN       NaN   156.0     NaN      NaN
# 4           NaN       NaN       NaN       NaN     NaN     NaN      NaN
# ...         ...       ...       ...       ...     ...     ...      ...
# 1859  4066513.0       JPN       NaN       NaN   392.0     NaN      NaN
# 1860  4066513.0       JPN       NaN       NaN   392.0     NaN      NaN
# 1861  2488052.0       CHL       NaN       NaN   152.0     NaN      NaN
# 1862   963556.0       CHN       NaN       NaN   156.0     NaN      NaN
# 1863   963556.0       CHN       NaN       NaN   156.0     NaN      NaN
#
#       UN_TER1  UN_TER2 UN_TER3
# 0       752.0      NaN     NaN
# 1       360.0      NaN     NaN
# 2       840.0      NaN     NaN
# 3       156.0      NaN     NaN
# 4         NaN      NaN     NaN
# ...       ...      ...     ...
# 1859    392.0      NaN     NaN
# 1860    392.0      NaN     NaN
# 1861    152.0      NaN     NaN
# 1862    156.0      NaN     NaN
# 1863    156.0      NaN     NaN
#
# [1866 rows x 78 columns]

# %%
df_join
# Out:
#       Antenna Offset from Bow  Antenna Offset from Port  Beam  \
# 0                        77.0                      13.0  16.0
# 1                         0.0                       0.0   0.0
# 2                       119.0                       6.0  23.0
# 3                        25.0                       3.0   6.0
# 4                         NaN                       NaN   NaN
# ...                       ...                       ...   ...
# 1859                     56.0                       5.0  11.0
# 1860                      0.0                       0.0   0.0
# 1861                     14.0                       5.0  12.0
# 1862                      0.0                       0.0   0.0
# 1863                     92.0                       7.0  16.0
#
#                            Builder Call Sign  Cargo Type  \
# 0                              NaN     D5KN7    9-NoInfo
# 1                     Arie Taryo P    YB3789  0-AllShips
# 2                        Kitanihon     3FAF5  0-AllShips
# 3     Rongcheng Haida Shipbuilding     BBFB7  5-Reserved
# 4                   Flensburger KG       NaN         NaN
# ...                            ...       ...         ...
# 1859                     Wakamatsu     UBMG8  0-AllShips
# 1860             Watanabe Nagasaki    JD3401  0-AllShips
# 1861              Detroit Chile SA    CB9953  0-AllShips
# 1862                           NaN     BVBR7  8-Reserved
# 1863         Kyokuyo Shipyard Corp      HOAJ  0-AllShips
#
#                   Class Society    COG Beneficial Owner  Deadweight  ...  \
# 0                           NaN   98.3              NaN         NaN  ...
# 1                           NaN  221.3        Indonesia         NaN  ...
# 2           Nippon Kaiji Kyokai  304.0            Japan     10608.0  ...
# 3                           NaN   26.4            China         NaN  ...
# 4            Det Norske Veritas    0.0      Netherlands     10320.0  ...
# ...                         ...    ...              ...         ...  ...
# 1859  Russian Maritime Register  238.0           Russia      1056.0  ...
# 1860                        NaN  129.5            Japan         NaN  ...
# 1861                        NaN  211.2            Chile      1049.0  ...
# 1862                        NaN  223.7              NaN         NaN  ...
# 1863        Nippon Kaiji Kyokai  311.0      South Korea      5609.0  ...
#
#        AREA_KM2  ISO_SOV1  ISO_SOV2  ISO_SOV3 UN_SOV1 UN_SOV2  UN_SOV3  \
# 0      155347.0       SWE       NaN       NaN   752.0     NaN      NaN
# 1     6020917.0       IDN       NaN       NaN   360.0     NaN      NaN
# 2     2451023.0       USA       NaN       NaN   840.0     NaN      NaN
# 3      963556.0       CHN       NaN       NaN   156.0     NaN      NaN
# 4           NaN       NaN       NaN       NaN     NaN     NaN      NaN
# ...         ...       ...       ...       ...     ...     ...      ...
# 1859  4066513.0       JPN       NaN       NaN   392.0     NaN      NaN
# 1860  4066513.0       JPN       NaN       NaN   392.0     NaN      NaN
# 1861  2488052.0       CHL       NaN       NaN   152.0     NaN      NaN
# 1862   963556.0       CHN       NaN       NaN   156.0     NaN      NaN
# 1863   963556.0       CHN       NaN       NaN   156.0     NaN      NaN
#
#       UN_TER1  UN_TER2 UN_TER3
# 0       752.0      NaN     NaN
# 1       360.0      NaN     NaN
# 2       840.0      NaN     NaN
# 3       156.0      NaN     NaN
# 4         NaN      NaN     NaN
# ...       ...      ...     ...
# 1859    392.0      NaN     NaN
# 1860    392.0      NaN     NaN
# 1861    152.0      NaN     NaN
# 1862    156.0      NaN     NaN
# 1863    156.0      NaN     NaN
#
# [1866 rows x 78 columns]

# %%
result = df_join #[["MMSI", "Latitude", "Longitude", "MRGID_TER1", "TERRITORY1", "TERRITORY2","SOVEREIGN1", "SOVEREIGN2"]]

# %%
result.columns
# Out:
# Index(['Antenna Offset from Bow', 'Antenna Offset from Port', 'Beam',
#        'Builder', 'Call Sign', 'Cargo Type', 'Class Society', 'COG',
#        'Beneficial Owner', 'Deadweight', 'Destination', 'Design Draft',
#        'Draft Present Load', 'ETA', 'Fishing Number', 'Flag', 'Gross Tonnage',
#        'Heading', 'IMO Number', 'Last Port of Call', 'Latitude', 'Length',
#        'Longitude', 'MMSI', 'Name', 'Navigation Status', 'Official Number',
#        'Operator', 'Registered Owner', 'P And I Club', 'Port Of Registry',
#        'Propulsion Type', 'Sat Com', 'Sat Com Ansbk Code', 'Ship Type',
#        'Speed', 'Status', 'Sub Status', 'Subtype', 'Time of Fix (formatted)',
#        'Time of Fix (s since 1970)', 'Vessel Type', 'Year Built',
#        'Design Speed', 'Double Hull', 'coordinates', 'index_right', 'MRGID',
#        'GEONAME', 'MRGID_TER1', 'POL_TYPE', 'MRGID_SOV1', 'TERRITORY1',
#        'ISO_TER1', 'SOVEREIGN1', 'MRGID_TER2', 'MRGID_SOV2', 'TERRITORY2',
#        'ISO_TER2', 'SOVEREIGN2', 'MRGID_TER3', 'MRGID_SOV3', 'TERRITORY3',
#        'ISO_TER3', 'SOVEREIGN3', 'X_1', 'Y_1', 'MRGID_EEZ', 'AREA_KM2',
#        'ISO_SOV1', 'ISO_SOV2', 'ISO_SOV3', 'UN_SOV1', 'UN_SOV2', 'UN_SOV3',
#        'UN_TER1', 'UN_TER2', 'UN_TER3'],
#       dtype='object')

# %%
df_join['ISO_TER1'].isna().mean()
# Out:
# 0.3435155412647374

# %%
result.to_csv('data/current_location.csv')
